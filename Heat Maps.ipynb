# %%
import pandas as pd
import numpy as np
import seaborn as sns                       
import matplotlib.pyplot as plt    
get_ipython().run_line_magic('matplotlib', 'inline')
sns.set(color_codes=True)


# In[2]:


df = pd.read_csv("Churn Modeling.csv")
df  
#1)
#Delete the information you don't want
df = df.drop(["Surname", "RowNumber"], axis=1)
#2)
#Converting write information to binary
df =pd.get_dummies(df,drop_first=True)
#Heat Maps
plt.figure(figsize=(10,5))
c= df.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
#                    CustomerId  CreditScore       Age    Tenure   Balance  \
# CustomerId           1.000000     0.005308  0.009497 -0.014883 -0.012419
# CreditScore          0.005308     1.000000 -0.003965  0.000842  0.006268
# Age                  0.009497    -0.003965  1.000000 -0.009997  0.028308
# Tenure              -0.014883     0.000842 -0.009997  1.000000 -0.012254
# Balance             -0.012419     0.006268  0.028308 -0.012254  1.000000
# NumOfProducts        0.016972     0.012238 -0.030680  0.013444 -0.304180
# HasCrCard           -0.014025    -0.005458 -0.011721  0.022583 -0.014858
# IsActiveMember       0.001665     0.025651  0.085472 -0.028362 -0.010084
# EstimatedSalary      0.015271    -0.001384 -0.007201  0.007784  0.012797
# Exited              -0.006248    -0.027094  0.285323 -0.014001  0.118533
# Geography_Germany   -0.003097     0.005538  0.046897 -0.000567  0.401110
# Geography_Spain      0.007800     0.004780 -0.001685  0.003868 -0.134892
# Gender_Male         -0.002641    -0.002857 -0.027544  0.014733  0.012087
#
#                    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# CustomerId              0.016972  -0.014025        0.001665         0.015271
# CreditScore             0.012238  -0.005458        0.025651        -0.001384
# Age                    -0.030680  -0.011721        0.085472        -0.007201
# Tenure                  0.013444   0.022583       -0.028362         0.007784
# Balance                -0.304180  -0.014858       -0.010084         0.012797
# NumOfProducts           1.000000   0.003183        0.009612         0.014204
# HasCrCard               0.003183   1.000000       -0.011866        -0.009933
# IsActiveMember          0.009612  -0.011866        1.000000        -0.011421
# EstimatedSalary         0.014204  -0.009933       -0.011421         1.000000
# Exited                 -0.047820  -0.007138       -0.156128         0.012097
# Geography_Germany      -0.010419   0.010577       -0.020486         0.010297
# Geography_Spain         0.009039  -0.013480        0.016732        -0.006482
# Gender_Male            -0.021859   0.005766        0.022544        -0.008112
#
#                      Exited  Geography_Germany  Geography_Spain  Gender_Male
# CustomerId        -0.006248          -0.003097         0.007800    -0.002641
# CreditScore       -0.027094           0.005538         0.004780    -0.002857
# Age                0.285323           0.046897        -0.001685    -0.027544
# Tenure            -0.014001          -0.000567         0.003868     0.014733
# Balance            0.118533           0.401110        -0.134892     0.012087
# NumOfProducts     -0.047820          -0.010419         0.009039    -0.021859
# HasCrCard         -0.007138           0.010577        -0.013480     0.005766
# IsActiveMember    -0.156128          -0.020486         0.016732     0.022544
# EstimatedSalary    0.012097           0.010297        -0.006482    -0.008112
# Exited             1.000000           0.173488        -0.052667    -0.106512
# Geography_Germany  0.173488           1.000000        -0.332084    -0.024628
# Geography_Spain   -0.052667          -0.332084         1.000000     0.016889
# Gender_Male       -0.106512          -0.024628         0.016889     1.000000
